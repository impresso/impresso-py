# %%
from impresso import connect

impresso = connect("https://dev.impresso-project.ch/public-api", persisted_token=True)
# Out:
# 🎉 You are now connected to the Impresso API!  🎉

# %% [markdown]
# # Search collections

# %%
result = impresso.collections.find()
result.df
# Out:
#                                                                name  \
# uid
# local-roka-YOUfhywk                                rk-test-celery-1
# local-roka-UaJ1domy  estelle-test-collection-for-recsys-not-working
# local-roka-m-dkOd7b                       table-chair-pulpe-6-items
# local-roka-LCkL6Kyp                            lexpress-table-chair
# local-roka-tOrwrOG3                    coronavirus-pandemie-3-items
# local-roka-38ewMeeH                                    test_regions
# local-roka-h5pz8bqT             grippe AND virus WITH economy topic
# local-roka-FZ7Scq9u                             guerre-schengen-vin
# local-roka--Wg0reEz                                            test
#
#                                                            description status  \
# uid
# local-roka-YOUfhywk                                       x12345678901    PRI
# local-roka-UaJ1domy   containing paris roubaix or paris roubais or ...    PRI
# local-roka-m-dkOd7b   containing table, chair AND pulpe of L'Expres...    PRI
# local-roka-LCkL6Kyp   containing table AND chair of L'Express publi...    PRI
# local-roka-tOrwrOG3               containing coronavirus AND pandemie     PRI
# local-roka-38ewMeeH                                                       PRI
# local-roka-h5pz8bqT   containing grippe and virus with topic "budge...    PRI
# local-roka-FZ7Scq9u                                                       PRI
# local-roka--Wg0reEz                                                       PRI
#
#                                   creationDate  \
# uid
# local-roka-YOUfhywk  2024-05-07T08:50:20+00:00
# local-roka-UaJ1domy  2020-09-24T09:11:42+00:00
# local-roka-m-dkOd7b  2020-09-04T13:41:55+00:00
# local-roka-LCkL6Kyp  2020-09-04T13:39:41+00:00
# local-roka-tOrwrOG3  2020-09-04T13:14:48+00:00
# local-roka-38ewMeeH  2020-05-06T13:34:30+00:00
# local-roka-h5pz8bqT  2020-04-16T11:18:11+00:00
# local-roka-FZ7Scq9u  2020-02-10T10:15:37+00:00
# local-roka--Wg0reEz  2019-10-10T14:56:05+00:00
#
#                                      lastModifiedDate  countItems  \
# uid
# local-roka-YOUfhywk         2024-05-07T08:50:20+00:00           0
# local-roka-UaJ1domy  2020-09-24T09:14:51.970000+00:00        6193
# local-roka-m-dkOd7b         2020-09-04T13:41:55+00:00           0
# local-roka-LCkL6Kyp         2020-09-04T13:39:41+00:00           0
# local-roka-tOrwrOG3  2020-09-04T13:14:50.249000+00:00           3
# local-roka-38ewMeeH         2020-05-06T13:34:30+00:00           0
# local-roka-h5pz8bqT  2020-04-16T11:18:23.792000+00:00         100
# local-roka-FZ7Scq9u         2020-02-10T10:15:37+00:00           0
# local-roka--Wg0reEz         2019-10-10T14:56:05+00:00           0
#
#                                    labels creator.uid creator.username
# uid
# local-roka-YOUfhywk  [bucket, collection]  local-roka   roman.kalyakin
# local-roka-UaJ1domy  [bucket, collection]  local-roka   roman.kalyakin
# local-roka-m-dkOd7b  [bucket, collection]  local-roka   roman.kalyakin
# local-roka-LCkL6Kyp  [bucket, collection]  local-roka   roman.kalyakin
# local-roka-tOrwrOG3  [bucket, collection]  local-roka   roman.kalyakin
# local-roka-38ewMeeH  [bucket, collection]  local-roka   roman.kalyakin
# local-roka-h5pz8bqT  [bucket, collection]  local-roka   roman.kalyakin
# local-roka-FZ7Scq9u  [bucket, collection]  local-roka   roman.kalyakin
# local-roka--Wg0reEz  [bucket, collection]  local-roka   roman.kalyakin

# %% [markdown]
# # Get collection

# %%
result = impresso.collections.get("local-roka-tOrwrOG3")
result.df
# Out:
#                                              name  \
# uid
# local-roka-tOrwrOG3  coronavirus-pandemie-3-items
#
#                                                description status  \
# uid
# local-roka-tOrwrOG3   containing coronavirus AND pandemie     PRI
#
#                                   creationDate  \
# uid
# local-roka-tOrwrOG3  2020-09-04T13:14:48+00:00
#
#                                      lastModifiedDate  countItems  \
# uid
# local-roka-tOrwrOG3  2020-09-04T13:14:50.249000+00:00           3
#
#                                    labels creator.uid creator.username
# uid
# local-roka-tOrwrOG3  [bucket, collection]  local-roka   roman.kalyakin
