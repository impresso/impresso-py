# %%
from impresso import connect

impresso = connect()
# Out:
# 🎉 You are now connected to the Impresso API!  🎉
# 🔗 Using API: https://dev.impresso-project.ch/public-api

# %% [markdown]
# # Search collections
#
# Find all collections that your Impresso account owns.

# %%
result = impresso.collections.find()
result
# Out:
# <h2>FindCollections result</h2>
# <div>Contains <b>9</b> items of <b>9</b> total items.</div>
# <br/>
# See this result in the <a href="https://dev.impresso-project.ch/app/collections?">Impresso App</a>.
# <h3>Data preview:</h3>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>description</th>
#       <th>status</th>
#       <th>creationDate</th>
#       <th>lastModifiedDate</th>
#       <th>countItems</th>
#       <th>labels</th>
#       <th>creator.uid</th>
#       <th>creator.username</th>
#     </tr>
#     <tr>
#       <th>uid</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>local-roka-YOUfhywk</th>
#       <td>rk-test-celery-1</td>
#       <td>x12345678901</td>
#       <td>PRI</td>
#       <td>2024-05-07T08:50:20+00:00</td>
#       <td>2024-08-14T15:18:18.871000+00:00</td>
#       <td>1</td>
#       <td>[bucket, collection]</td>
#       <td>local-roka</td>
#       <td>roman.kalyakin</td>
#     </tr>
#     <tr>
#       <th>local-roka-UaJ1domy</th>
#       <td>estelle-test-collection-for-recsys-not-working</td>
#       <td>containing paris roubaix or paris roubais or ...</td>
#       <td>PRI</td>
#       <td>2020-09-24T09:11:42+00:00</td>
#       <td>2020-09-24T09:14:51.970000+00:00</td>
#       <td>6193</td>
#       <td>[bucket, collection]</td>
#       <td>local-roka</td>
#       <td>roman.kalyakin</td>
#     </tr>
#     <tr>
#       <th>local-roka-m-dkOd7b</th>
#       <td>table-chair-pulpe-6-items</td>
#       <td>containing table, chair AND pulpe of L'Expres...</td>
#       <td>PRI</td>
#       <td>2020-09-04T13:41:55+00:00</td>
#       <td>2020-09-04T13:41:55+00:00</td>
#       <td>0</td>
#       <td>[bucket, collection]</td>
#       <td>local-roka</td>
#       <td>roman.kalyakin</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Get collection
#
# Get metadata of a colection by its ID.

# %%
result = impresso.collections.get("local-roka-tOrwrOG3")
result
# Out:
# <h2>GetCollection result</h2>
# <div>Contains <b>1</b> items of <b>1</b> total items.</div>
# <br/>
# See this result in the <a href="https://dev.impresso-project.ch/app/collections/local-roka-tOrwrOG3">Impresso App</a>.
# <h3>Data preview:</h3>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>description</th>
#       <th>status</th>
#       <th>creationDate</th>
#       <th>lastModifiedDate</th>
#       <th>countItems</th>
#       <th>labels</th>
#       <th>creator.uid</th>
#       <th>creator.username</th>
#     </tr>
#     <tr>
#       <th>uid</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>local-roka-tOrwrOG3</th>
#       <td>coronavirus-pandemie-3-items</td>
#       <td>containing coronavirus AND pandemie</td>
#       <td>PRI</td>
#       <td>2020-09-04T13:14:48+00:00</td>
#       <td>2020-09-04T13:14:50.249000+00:00</td>
#       <td>3</td>
#       <td>[bucket, collection]</td>
#       <td>local-roka</td>
#       <td>roman.kalyakin</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Get collection items
#
# Get items from a collection by its ID.

# %%
colection_id = result.raw["uid"]
items = impresso.collections.items(colection_id)
items
# Out:
# <h2>Search result</h2>
# <div>Contains <b>3</b> items of <b>3</b> total items.</div>
# <br/>
# See this result in the <a href="https://dev.impresso-project.ch/app/search?sq=ChcYEyoTbG9jYWwtcm9rYS10T3J3ck9HMw==&p=1">Impresso App</a>.
# <h3>Data preview:</h3>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>title</th>
#       <th>size</th>
#       <th>nbPages</th>
#       <th>pages</th>
#       <th>isCC</th>
#       <th>excerpt</th>
#       <th>labels</th>
#       <th>accessRight</th>
#       <th>year</th>
#       <th>locations</th>
#       <th>persons</th>
#       <th>language</th>
#       <th>matches</th>
#       <th>regions</th>
#       <th>regionBreaks</th>
#       <th>contentLineBreaks</th>
#       <th>isFront</th>
#       <th>date</th>
#       <th>country</th>
#       <th>tags</th>
#       <th>collections</th>
#       <th>dataProvider</th>
#       <th>topics</th>
#       <th>mentions</th>
#       <th>issue.uid</th>
#       <th>issue.cover</th>
#       <th>issue.labels</th>
#       <th>issue.fresh</th>
#       <th>issue.accessRights</th>
#       <th>issue.date</th>
#       <th>issue.year</th>
#       <th>newspaper.uid</th>
#       <th>newspaper.acronym</th>
#       <th>newspaper.labels</th>
#       <th>newspaper.languages</th>
#       <th>newspaper.included</th>
#       <th>newspaper.name</th>
#       <th>newspaper.endYear</th>
#       <th>newspaper.startYear</th>
#       <th>newspaper.countArticles</th>
#       <th>newspaper.countIssues</th>
#       <th>newspaper.countPages</th>
#       <th>newspaper.deltaYear</th>
#       <th>newspaper.properties</th>
#       <th>newspaper.firstIssue.uid</th>
#       <th>newspaper.firstIssue.cover</th>
#       <th>newspaper.firstIssue.labels</th>
#       <th>newspaper.firstIssue.fresh</th>
#       <th>newspaper.firstIssue.accessRights</th>
#       <th>newspaper.firstIssue.date</th>
#       <th>newspaper.firstIssue.year</th>
#       <th>newspaper.lastIssue.uid</th>
#       <th>newspaper.lastIssue.cover</th>
#       <th>newspaper.lastIssue.labels</th>
#       <th>newspaper.lastIssue.fresh</th>
#       <th>newspaper.lastIssue.accessRights</th>
#       <th>newspaper.lastIssue.date</th>
#       <th>newspaper.lastIssue.year</th>
#       <th>newspaper.fetched</th>
#     </tr>
#     <tr>
#       <th>uid</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EXP-2015-06-18-a-i0190</th>
#       <td>ar</td>
#       <td>Coronavirus Mers, le signal d’alarme</td>
#       <td>166</td>
#       <td>1</td>
#       <td>[{'uid': 'EXP-2015-06-18-a-p0021', 'num': 21, ...</td>
#       <td>False</td>
#       <td>Coronavirus Mers, le signal d’alarme INFECTION...</td>
#       <td>[article]</td>
#       <td>OpenPrivate</td>
#       <td>2015</td>
#       <td>[{'uid': 'aida-0001-54-Gare_de_Cornavin', 'rel...</td>
#       <td>[{'uid': 'aida-0001-50-Keiji_Fukuda', 'relevan...</td>
#       <td>fr</td>
#       <td>[]</td>
#       <td>[{'pageUid': 'EXP-2015-06-18-a-p0021', 'coords...</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>False</td>
#       <td>2015-06-18T00:00:00+00:00</td>
#       <td>CH</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>SNL</td>
#       <td>[{'relevance': 0.536, 'topic': {'uid': '', 'la...</td>
#       <td>[]</td>
#       <td>EXP-2015-06-18-a</td>
#       <td></td>
#       <td>[issue]</td>
#       <td>False</td>
#       <td>NotDefined</td>
#       <td>2015-06-18T00:00:00+00:00</td>
#       <td>2015</td>
#       <td>EXP</td>
#       <td>EXP</td>
#       <td>[newspaper]</td>
#       <td>[fr]</td>
#       <td>True</td>
#       <td>L'Express</td>
#       <td>2018</td>
#       <td>1738</td>
#       <td>8397287</td>
#       <td>46204</td>
#       <td>701819</td>
#       <td>280</td>
#       <td>[]</td>
#       <td>EXP-1740-01-01-a</td>
#       <td></td>
#       <td>[issue]</td>
#       <td>False</td>
#       <td>Closed</td>
#       <td>1740-01-01T00:00:00+00:00</td>
#       <td>1740</td>
#       <td>EXP-2017-10-31-a</td>
#       <td></td>
#       <td>[issue]</td>
#       <td>False</td>
#       <td>Closed</td>
#       <td>2017-10-31T00:00:00+00:00</td>
#       <td>2017</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>IMP-2013-07-06-a-i0188</th>
#       <td>ar</td>
#       <td>L’OMS tiendra une consultation urgente</td>
#       <td>332</td>
#       <td>1</td>
#       <td>[{'uid': 'IMP-2013-07-06-a-p0021', 'num': 21, ...</td>
#       <td>True</td>
#       <td>L’OMS tiendra une consultation urgente SANTÉL’...</td>
#       <td>[article]</td>
#       <td>OpenPrivate</td>
#       <td>2013</td>
#       <td>[{'uid': 'aida-0001-54-Mecca', 'relevance': 1}]</td>
#       <td>[{'uid': 'aida-0001-50-Keiji_Fukuda', 'relevan...</td>
#       <td>fr</td>
#       <td>[]</td>
#       <td>[{'pageUid': 'IMP-2013-07-06-a-p0021', 'coords...</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>False</td>
#       <td>2013-07-06T00:00:00+00:00</td>
#       <td>CH</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>SNL</td>
#       <td>[{'relevance': 0.021, 'topic': {'uid': '', 'la...</td>
#       <td>[]</td>
#       <td>IMP-2013-07-06-a</td>
#       <td></td>
#       <td>[issue]</td>
#       <td>False</td>
#       <td>NotDefined</td>
#       <td>2013-07-06T00:00:00+00:00</td>
#       <td>2013</td>
#       <td>IMP</td>
#       <td>IMP</td>
#       <td>[newspaper]</td>
#       <td>[fr]</td>
#       <td>True</td>
#       <td>L'Impartial</td>
#       <td>2018</td>
#       <td>1881</td>
#       <td>7103161</td>
#       <td>40228</td>
#       <td>756672</td>
#       <td>137</td>
#       <td>[]</td>
#       <td>IMP-1881-01-01-a</td>
#       <td></td>
#       <td>[issue]</td>
#       <td>False</td>
#       <td>Closed</td>
#       <td>1881-01-01T00:00:00+00:00</td>
#       <td>1881</td>
#       <td>IMP-2018-01-22-a</td>
#       <td></td>
#       <td>[issue]</td>
#       <td>False</td>
#       <td>Closed</td>
#       <td>2018-01-22T00:00:00+00:00</td>
#       <td>2018</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>EXP-2013-07-06-a-i0181</th>
#       <td>ar</td>
#       <td>L’OMS tiendra une consultation urgente</td>
#       <td>332</td>
#       <td>1</td>
#       <td>[{'uid': 'EXP-2013-07-06-a-p0021', 'num': 21, ...</td>
#       <td>False</td>
#       <td>L’OMS tiendra une consultation urgente SANTÉL’...</td>
#       <td>[article]</td>
#       <td>OpenPrivate</td>
#       <td>2013</td>
#       <td>[{'uid': 'aida-0001-54-Mecca', 'relevance': 1}]</td>
#       <td>[{'uid': 'aida-0001-50-Keiji_Fukuda', 'relevan...</td>
#       <td>fr</td>
#       <td>[]</td>
#       <td>[{'pageUid': 'EXP-2013-07-06-a-p0021', 'coords...</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>False</td>
#       <td>2013-07-06T00:00:00+00:00</td>
#       <td>CH</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>SNL</td>
#       <td>[{'relevance': 0.391, 'topic': {'uid': '', 'la...</td>
#       <td>[]</td>
#       <td>EXP-2013-07-06-a</td>
#       <td></td>
#       <td>[issue]</td>
#       <td>False</td>
#       <td>NotDefined</td>
#       <td>2013-07-06T00:00:00+00:00</td>
#       <td>2013</td>
#       <td>EXP</td>
#       <td>EXP</td>
#       <td>[newspaper]</td>
#       <td>[fr]</td>
#       <td>True</td>
#       <td>L'E

# %% [markdown]
# ## Remove items from collection

# %%
item_id = items.pydantic.data[0].uid
item_id
# Out:
# 'EXP-2015-06-18-a-i0190'

# %%
impresso.collections.remove_items(colection_id, [item_id])

# %% [markdown]
# ## Add items to collection

# %%
impresso.collections.add_items(colection_id, [item_id])
