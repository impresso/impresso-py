# %%
from impresso import connect

impresso = connect()
# Out:
# 🎉 You are now connected to the Impresso API!  🎉
# 🔗 Using API: https://dev.impresso-project.ch/public-api/v1

# %% [markdown]
# ## Search images

# %%
result = impresso.images.find(term="rocket")
result
# Out:
# <div style="display: grid; ">
# <div>
# <h2>FindImages result</h2>
# <div>Contains <b>6</b> items of <b>6</b> total items.</div>
# <br/>
# See this result in the <a href="https://impresso-project.ch/app/images?q=rocket">Impresso App</a>.
# </div>
# </div>
# <h3>Data preview:</h3>
# <style type="text/css">
# </style>
# <table id="T_d29f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d29f4_level0_col0" class="col_heading level0 col0" >issueUid</th>
#       <th id="T_d29f4_level0_col1" class="col_heading level0 col1" >previewImage</th>
#       <th id="T_d29f4_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_d29f4_level0_col3" class="col_heading level0 col3" >caption</th>
#       <th id="T_d29f4_level0_col4" class="col_heading level0 col4" >pageNumbers</th>
#       <th id="T_d29f4_level0_col5" class="col_heading level0 col5" >mediaSourceRef.uid</th>
# ...

# %% [markdown]
# ## Image embedding search

# %%
image_id = "luxwort-1930-09-26-a-i0036"
image = impresso.images.get(image_id, include_embeddings=True)
image
# Out:
# <div style="display: grid; ">
# <div>
# <h2>GetImage result</h2>
# <div>Contains <b>0</b> items of <b>0</b> total items.</div>
# <br/>
# See this result in the <a href="https://impresso-project.ch/app/issue/luxwort-1930-09-26-a/view?articleId=i0036">Impresso App</a>.
# </div>
# </div>
# <h3>Data preview:</h3>
# <style type="text/css">
# </style>
# <table id="T_026e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_026e6_level0_col0" class="col_heading level0 col0" >issueUid</th>
#       <th id="T_026e6_level0_col1" class="col_heading level0 col1" >previewImage</th>
#       <th id="T_026e6_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_026e6_level0_col3" class="col_heading level0 col3" >caption</th>
#       <th id="T_026e6_level0_col4" class="col_heading level0 col4" >pageNumbers</th>
#       <th id="T_026e6_level0_col5" class="col_heading level0 col5" >embeddings</th>
# ...

# %%
embeddings = impresso.images.get_embeddings(image_id)
embeddings
# Out:
# ['openclip-768:...',
#  'dinov2-1024:...']

# %%
impresso.images.find(
  embedding=embeddings[0],
  limit=3
)
# Out:
# <div style="display: grid; ">
# <div>
# <h2>FindImages result</h2>
# <div>Contains <b>3</b> items (<b>0</b> - <b>3</b>) of <b>6</b> total items.</div>
# <br/>
# See this result in the <a href="https://impresso-project.ch/app/images">Impresso App</a>.
# </div>
# </div>
# <h3>Data preview:</h3>
# <style type="text/css">
# </style>
# <table id="T_6923a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6923a_level0_col0" class="col_heading level0 col0" >issueUid</th>
#       <th id="T_6923a_level0_col1" class="col_heading level0 col1" >previewImage</th>
#       <th id="T_6923a_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_6923a_level0_col3" class="col_heading level0 col3" >caption</th>
#       <th id="T_6923a_level0_col4" class="col_heading level0 col4" >pageNumbers</th>
#       <th id="T_6923a_level0_col5" class="col_heading level0 col5" >mediaSourceRef.uid</th>
# ...

# %%
impresso.images.find(
  embedding=embeddings[1],
  limit=3
)
# Out:
# <div style="display: grid; ">
# <div>
# <h2>FindImages result</h2>
# <div>Contains <b>3</b> items (<b>0</b> - <b>3</b>) of <b>6</b> total items.</div>
# <br/>
# See this result in the <a href="https://impresso-project.ch/app/images">Impresso App</a>.
# </div>
# </div>
# <h3>Data preview:</h3>
# <style type="text/css">
# </style>
# <table id="T_7fbf6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fbf6_level0_col0" class="col_heading level0 col0" >issueUid</th>
#       <th id="T_7fbf6_level0_col1" class="col_heading level0 col1" >previewImage</th>
#       <th id="T_7fbf6_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_7fbf6_level0_col3" class="col_heading level0 col3" >caption</th>
#       <th id="T_7fbf6_level0_col4" class="col_heading level0 col4" >pageNumbers</th>
#       <th id="T_7fbf6_level0_col5" class="col_heading level0 col5" >mediaSourceRef.uid</th>
# ...

# %% [markdown]
# ### Out of corpus embeddings

# %%
impresso.images.find(
  embedding=impresso.tools.embed_text(text="belval", target="image"),
  # media_id="luxwort",
  limit=3
)
# Out:
# <div style="display: grid; ">
# <div>
# <h2>FindImages result</h2>
# <div>Contains <b>3</b> items (<b>0</b> - <b>3</b>) of <b>6</b> total items.</div>
# <br/>
# See this result in the <a href="https://impresso-project.ch/app/images">Impresso App</a>.
# </div>
# </div>
# <h3>Data preview:</h3>
# <style type="text/css">
# </style>
# <table id="T_0f0d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f0d7_level0_col0" class="col_heading level0 col0" >issueUid</th>
#       <th id="T_0f0d7_level0_col1" class="col_heading level0 col1" >previewImage</th>
#       <th id="T_0f0d7_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_0f0d7_level0_col3" class="col_heading level0 col3" >contentItemUid</th>
#       <th id="T_0f0d7_level0_col4" class="col_heading level0 col4" >pageNumbers</th>
#       <th id="T_0f0d7_level0_col5" class="col_heading level0 col5" >mediaSourceRef.uid</th>
# ...

# %%
impresso.tools.embed_image(image="https://upload.wikimedia.org/wikipedia/en/7/73/Trollface.png", target="image")
# Out:
# 'dinov2-1024:...'

# %%
impresso.images.find(
  embedding=impresso.tools.embed_image(image="https://upload.wikimedia.org/wikipedia/en/7/73/Trollface.png", target="image"),
  limit=3
)
# Out:
# <div style="display: grid; ">
# <div>
# <h2>FindImages result</h2>
# <div>Contains <b>3</b> items (<b>0</b> - <b>3</b>) of <b>6</b> total items.</div>
# <br/>
# See this result in the <a href="https://impresso-project.ch/app/images">Impresso App</a>.
# </div>
# </div>
# <h3>Data preview:</h3>
# <style type="text/css">
# </style>
# <table id="T_696a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_696a5_level0_col0" class="col_heading level0 col0" >issueUid</th>
#       <th id="T_696a5_level0_col1" class="col_heading level0 col1" >previewImage</th>
#       <th id="T_696a5_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_696a5_level0_col3" class="col_heading level0 col3" >contentItemUid</th>
#       <th id="T_696a5_level0_col4" class="col_heading level0 col4" >pageNumbers</th>
#       <th id="T_696a5_level0_col5" class="col_heading level0 col5" >mediaSourceRef.uid</th>
# ...
